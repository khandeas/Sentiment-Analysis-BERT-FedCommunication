# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
import json
import datetime
import re

# %%
fomc_link = 'https://www.federalreserve.gov/json/calendar.json'
re_tags = re.compile(r'(&lt;[//]?p|&gt;|&lt;br.*)')

# %%
# read the data from url

with urlopen(fomc_link) as url:
     data = json.loads(url.read())
        
# convert the data to dataframe for easy manipulation
df_events = pd.DataFrame(data['events'])

# %%
# filter by type - 'FOMC','Speeches','Beige'
type_filter = ['FOMC','Beige','Speeches']
df_filtered = df_events[df_events.type.isin(type_filter)]

# %%
df_filtered
# Out:
#     days                                        description link  \
# 0     17                                   Bank Supervision  NaN
# 1     16                            The Outlook for Housing  NaN
# 2      9          U.S. Economic Outlook and Monetary Policy  NaN
# 3      8         Modernizing the Community Reinvestment Act  NaN
# 4     25   &lt;p&gt;Meeting of November 4-5, 2020&lt;/p&gt;  NaN
# 5      7  &lt;p&gt;Meeting of September 15-16, 2020&lt;/...  NaN
# 6     19     &lt;p&gt;Meeting of July 28-29, 2020&lt;/p&gt;  NaN
# 7      1      &lt;p&gt;Meeting of June 9-10, 2020&lt;/p&gt;  NaN
# 8     20    &lt;p&gt;Meeting of April 28-29, 2020&lt;/p&gt;  NaN
# 9      8    &lt;p&gt;Meeting of March 17-18, 2020&lt;/p&gt;  NaN
# 10    19  &lt;p&gt;Meeting of January 28-29, 2020&lt;/p&gt;  NaN
# 11    18      Monetary Policy, Technology and Globalization  NaN
# 12    21                                                NaN  NaN
# 13     2                                                NaN  NaN
# 14    15                                                NaN  NaN
# 15    27                                                NaN  NaN
# 16    15                                                NaN  NaN
# 17     4                                                NaN  NaN
# 18     5  &lt;p&gt;Two-day meeting, November 4-5&lt;br /...  NaN
# 19    16  &lt;p&gt;Two-day meeting, September 15-16&lt;b...  NaN
# 20    29  &lt;p&gt;Two-day meeting, July 28-29&lt;br /&g...  NaN
# 21    10  &lt;p&gt;Two-day meeting, June 9-10&lt;br /&gt...  NaN
# 22    29  &lt;p&gt;Two-day meeting, April 28-29&lt;br /&...  NaN
# 23    18  &lt;p&gt;Two-day meeting, March 17-18&lt;br /&...  NaN
# 47     2                                                NaN  NaN
# 49    16  &lt;p&gt;Two-day meeting, December 15-16&lt;br...  NaN
# 164   26  Federal Reserve Framework Review of Monetary P...  NaN
# 166   25      Building on the Gains from the Long Expansion  NaN
# 173   15                                                NaN  NaN
# 174   29  &lt;p&gt;Two-day meeting, January 28-29&lt;br ...  NaN
# ..   ...                                                ...  ...
# 702   17                      Monetary Policy Communication  NaN
# 703   10  Discussion with Ford School Dean Susan M. Collins  NaN
# 704    4                                 Departing Thoughts  NaN
# 705   28  America&#39;s Central Bank: This History and S...  NaN
# 706   28  Addressing Workforce Development Challenges in...  NaN
# 707   23                                    Opening Remarks  NaN
# 709    3  &lt;p&gt;Meeting of December 12 - 13, 2017&lt;...  NaN
# 710   22  &lt;p&gt;Meeting of October 31- November 1, 20...  NaN
# 711   11  &lt;p&gt;Minutes of September 19 - 20, 2017&lt...  NaN
# 712   16   &lt;p&gt;Meeting of July 25 - 26, 2017&lt;/p&gt;  NaN
# 713    5   &lt;p&gt;Meeting of June 13 - 14, 2017&lt;/p&gt;  NaN
# 714   24      &lt;p&gt;Meeting of May 2 - 3, 2017&lt;/p&gt;  NaN
# 715    5  &lt;p&gt;Meeting of March 14 - 15, 2017&lt;/p&gt;  NaN
# 716   22  &lt;p&gt;Meeting of January 31 - February 1, 2...  NaN
# 717   29                                                NaN  NaN
# 718   18                                                NaN  NaN
# 719    6                                                NaN  NaN
# 720   12                                                NaN  NaN
# 721   31                                                NaN  NaN
# 722   19                                                NaN  NaN
# 723    1                                                NaN  NaN
# 724   18                                                NaN  NaN
# 876   13  &lt;p&gt;Two-day meeting, December 12 - 13&lt;...  NaN
# 877    1  &lt;p&gt;&lt;span&gt;&lt;span&gt;Two-day meeti...  NaN
# 878   20  &lt;p&gt;Two-day meeting, September 19 - 20&lt...  NaN
# 879   26     &lt;p&gt;Two-day meeting, July 25-26&lt;/p&gt;  NaN
# 880   14  &lt;p&gt;Two-day meeting, June 13-14&lt;br /&g...  NaN
# 881    3      &lt;p&gt;Two-day meeting, May 2 - 3&lt;/p&gt;  NaN
# 882   15  &lt;p&gt;Two-day meeting, March 14 - 15&lt;br ...  NaN
# 883    1  &lt;p&gt;&lt;span&gt;&lt;span&gt;Two-day meeti...  NaN
#
#                                                   live  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://www.urban.org/events/conversation-dr-l...
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   https://www.ecb.europa.eu/home/html/index.en.html
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 47                                                 NaN
# 49                                                 NaN
# 164                                                NaN
# 166                                                NaN
# 173                                                NaN
# 174                                                NaN
# ..                                                 ...
# 702                        https://livestream.com/sipa
# 703   http://fordschool.umich.edu/streaming/fed-chair/
# 704          https://www.youtube.com/user/WilsonSchool
# 705                                                NaN
# 706                                                NaN
# 707       https://www.youtube.com/user/FedReserveBoard
# 709                                                NaN
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
# 715                                                NaN
# 716                                                NaN
# 717                                                NaN
# 718                                                NaN
# 719                                                NaN
# 720                                                NaN
# 721                                                NaN
# 722                                                NaN
# 723                                                NaN
# 724                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
#
#                                               location    month        time  \
# 0    At the American Bar Association Banking Law Co...  2020-01  12:45 p.m.
# 1    At the Home Builders Association of Greater Ka...  2020-01  10:00 a.m.
# 2    At the C. Peter McColough Series on Internatio...  2020-01   8:00 a.m.
# 3    At in Conversation with Dr. Lael Brainard, Urb...  2020-01  10:00 a.m.
# 4                                                  NaN  2020-11   2:00 p.m.
# 5                                                  NaN  2020-10   2:00 p.m.
# 6                                                  NaN  2020-08   2:00 p.m.
# 7                                                  NaN  2020-07   2:00 p.m.
# 8                                                  NaN  2020-05   2:00 p.m.
# 9                                                  NaN  2020-04   2:00 p.m.
# 10                                                 NaN  2020-02   2:00 p.m.
# 11   At Colloquium in Honour of Benoît Coeuré, Euro...  2019-12   5:15 a.m.
# 12                                                 NaN  2020-10   2:00 p.m.
# 13                                                 NaN  2020-09   2:00 p.m.
# 14                                                 NaN  2020-07   2:00 p.m.
# 15                                                 NaN  2020-05   2:00 p.m.
# 16                                                 NaN  2020-04   2:00 p.m.
# 17                                                 NaN  2020-03   2:00 p.m.
# 18                                                 NaN  2020-11   2:00 p.m.
# 19                                                 NaN  2020-09   2:00 p.m.
# 20                                                 NaN  2020-07   2:00 p.m.
# 21                                                 NaN  2020-06   2:00 p.m.
# 22                                                 NaN  2020-04   2:00 p.m.
# 23                                                 NaN  2020-03   2:00 p.m.
# 47                                                 NaN  2020-12   2:00 p.m.
# 49                                                 NaN  2020-12   2:00 p.m.
# 164  At the New York Association for Business Econo...  2019-11   1:00 p.m.
# 166  At the Greater Providence Chamber of Commerce ...  2019-11   7:00 p.m.
# 173                                                NaN  2020-01   2:00 p.m.
# 174                                                NaN  2020-01   2:00 p.m.
# ..                                                 ...      ...         ...
# 702  Columbia University School of International an...  2017-04   5:00 p.m.
# 703  Gerald R. Ford School of Public Policy: Policy...  2017-04   4:10 p.m.
# 704  Princeton University Speech, Princeton Univers...  2017-04   4:30 p.m.
# 705  West Virginia University College of Business a...  2017-03   4:30 p.m.
# 706  At the National Community Reinvestment Coaliti...  2017-03  12:50 p.m.
# 707  At the 2017 Federal Reserve System Community D...  2017-03   8:45 a.m.
# 709                                                NaN  2018-01   2:00 p.m.
# 710                                                NaN  2017-11   2:00 p.m.
# 711                                                NaN  2017-10   2:00 p.m.
# 712                                                NaN  2017-08   2:00 p.m.
# 713                                                NaN  2017-07   2:00 p.m.
# 714                                                NaN  2017-05   2:00 p.m.
# 715                                                NaN  2017-04   2:00 p.m.
# 716                                                NaN  2017-02   2:00 p.m.
# 717                                                NaN  2017-11   2:00 p.m.
# 718                                                NaN  2017-10   2:00 p.m.
# 719                                                NaN  2017-09   2:00 p.m.
# 720                                                NaN  2017-07   2:00 p.m.
# 721                                                NaN  2017-05   2:00 p.m.
# 722                                                NaN  2017-04   2:00 p.m.
# 723                                                NaN  2017-03   2:00 p.m.
# 724                                                NaN  2017-01   2:00 p.m.
# 876                                                NaN  2017-12   2:00 p.m.
# 877                                                NaN  2017-11   2:00 p.m.
# 878                                                NaN  2017-09   2:00 p.m.
# 879                                                NaN  2017-07   2:00 p.m.
# 880                                                NaN  2017-06   2:00 p.m.
# 881                                                NaN  2017-05   2:00 p.m.
# 882                                                NaN  2017-03   2:00 p.m.
# 883                                                NaN  2017-02   2:00 p.m.
#
#                                        title      type
# 0    Speech -- Vice Chair Randal K. Quarles   Speeches
# 1        Speech -- Governor Michelle Bowman   Speeches
# 2     Speech - Vice Chair Richard H. Clarida  Speeches
# 3            Speech - Governor Lael Brainard  Speeches
# 4                               FOMC Minutes      FOMC
# 5                               FOMC Minutes      FOMC
# 6                               FOMC Minutes      FOMC
# 7                               FOMC Minutes      FOMC
# 8                               FOMC Minutes      FOMC
# 9                               FOMC Minutes      FOMC
# 10                              FOMC Minutes      FOMC
# 11          Speech -- Governor Lael Brainard  Speeches
# 12                                Beige Book     Beige
# 13                                Beige Book     Beige
# 14                                Beige Book     Beige
# 15                                Beige Book     Beige
# 16                                Beige Book     Beige
# 17                                Beige Book     Beige
# 18                              FOMC Meeting      FOMC
# 19                              FOMC Meeting      FOMC
# 20                              FOMC Meeting      FOMC
# 21                              FOMC Meeting      FOMC
# 22                              FOMC Meeting      FOMC
# 23                              FOMC Meeting      FOMC
# 47                                Beige Book     Beige
# 49                              FOMC Meeting      FOMC
# 164           Speech--Governor Lael Brainard  Speeches
# 166           Speech--Chair Jerome H. Powell  Speeches
# 173                               Beige Book     Beige
# 174                             FOMC Meeting      FOMC
# ..                                       ...       ...
# 702    Speech--Vice Chairman Stanley Fischer  Speeches
# 703        Discussion--Chair Janet L. Yellen  Speeches
# 704       Speech--Governor Daniel K. Tarullo  Speeches
# 705       Speech - Governor Jerome H. Powell  Speeches
# 706           Speech - Chair Janet L. Yellen  Speeches
# 707           Speech - Chair Janet L. Yellen  Speeches
# 709                             FOMC Minutes      FOMC
# 710                             FOMC Minutes      FOMC
# 711                             FOMC Minutes      FOMC
# 712                             FOMC Minutes      FOMC
# 713                             FOMC Minutes      FOMC
# 714                             FOMC Minutes      FOMC
# 715                             FOMC Minutes      FOMC
# 716                             FOMC Minutes      FOMC
# 717                               Beige Book     Beige
# 718                               Beige Book     Beige
# 719                               Beige Book     Beige
# 720                               Beige Book     Beige
# 721                               Beige Book     Beige
# 722                               Beige Book     Beige
# 723                               Beige Book     Beige
# 724                               Beige Book     Beige
# 876                             FOMC meeting      FOMC
# 877                             FOMC meeting      FOMC
# 878                             FOMC meeting      FOMC
# 879                             FOMC meeting      FOMC
# 880                             FOMC meeting      FOMC
# 881                             FOMC meeting      FOMC
# 882                             FOMC Meeting      FOMC
# 883                             FOMC Meeting      FOMC
#
# [255 rows x 9 columns]

# %%
def filter_records(events):
    '''
    This function strips out relavent event details from
    each row in the dataframe
    '''
   
    # extract date and time
    current_date = datetime.datetime.now()   
    event_datestr = events['days'] + '-' + events['month'] + ',' \
                    + events['time'].replace(' p.m.','PM').replace(' a.m.','AM')
    event_datetime = datetime.datetime.strptime(event_datestr,'%d-%Y-%m,%I:%M%p')
    
    # if the event is for the future
    if event_datetime > current_date:        
        try:          
            filtered_description = re.sub(re_tags,'',events['description'])
        except:
            filtered_description = str(events['title']) + ' ' + str(event_datetime.date())
            
        final_record = {'date':event_datetime, 'description':filtered_description, \
                        'title':events['title'], 'category':events['type']}
        return final_record
    else:
        return np.nan

# %%
#apply the filter records function in parallel. get the results
df_result = df_filtered.apply(filter_records,axis=1)

# %%
#create the final data frame.
df_final = pd.DataFrame(list(df_result.dropna().values))

# %%
df_final
# Out:
#     category                date                       description  \
# 0   Speeches 2020-01-17 12:45:00                  Bank Supervision
# 1   Speeches 2020-01-16 10:00:00           The Outlook for Housing
# 2       FOMC 2020-11-25 14:00:00     Meeting of November 4-5, 2020
# 3       FOMC 2020-10-07 14:00:00  Meeting of September 15-16, 2020
# 4       FOMC 2020-08-19 14:00:00       Meeting of July 28-29, 2020
# 5       FOMC 2020-07-01 14:00:00        Meeting of June 9-10, 2020
# 6       FOMC 2020-05-20 14:00:00      Meeting of April 28-29, 2020
# 7       FOMC 2020-04-08 14:00:00      Meeting of March 17-18, 2020
# 8       FOMC 2020-02-19 14:00:00    Meeting of January 28-29, 2020
# 9      Beige 2020-10-21 14:00:00             Beige Book 2020-10-21
# 10     Beige 2020-09-02 14:00:00             Beige Book 2020-09-02
# 11     Beige 2020-07-15 14:00:00             Beige Book 2020-07-15
# 12     Beige 2020-05-27 14:00:00             Beige Book 2020-05-27
# 13     Beige 2020-04-15 14:00:00             Beige Book 2020-04-15
# 14     Beige 2020-03-04 14:00:00             Beige Book 2020-03-04
# 15      FOMC 2020-11-05 14:00:00     Two-day meeting, November 4-5
# 16      FOMC 2020-09-16 14:00:00  Two-day meeting, September 15-16
# 17      FOMC 2020-07-29 14:00:00       Two-day meeting, July 28-29
# 18      FOMC 2020-06-10 14:00:00        Two-day meeting, June 9-10
# 19      FOMC 2020-04-29 14:00:00      Two-day meeting, April 28-29
# 20      FOMC 2020-03-18 14:00:00      Two-day meeting, March 17-18
# 21     Beige 2020-12-02 14:00:00             Beige Book 2020-12-02
# 22      FOMC 2020-12-16 14:00:00   Two-day meeting, December 15-16
# 23     Beige 2020-01-15 14:00:00             Beige Book 2020-01-15
# 24      FOMC 2020-01-29 14:00:00    Two-day meeting, January 28-29
#
#                                       title
# 0   Speech -- Vice Chair Randal K. Quarles
# 1       Speech -- Governor Michelle Bowman
# 2                              FOMC Minutes
# 3                              FOMC Minutes
# 4                              FOMC Minutes
# 5                              FOMC Minutes
# 6                              FOMC Minutes
# 7                              FOMC Minutes
# 8                              FOMC Minutes
# 9                                Beige Book
# 10                               Beige Book
# 11                               Beige Book
# 12                               Beige Book
# 13                               Beige Book
# 14                               Beige Book
# 15                             FOMC Meeting
# 16                             FOMC Meeting
# 17                             FOMC Meeting
# 18                             FOMC Meeting
# 19                             FOMC Meeting
# 20                             FOMC Meeting
# 21                               Beige Book
# 22                             FOMC Meeting
# 23                               Beige Book
# 24                             FOMC Meeting

# %%
df_final[df_final['category']=='Beige']
# Out:
#    category                date            description       title
# 9     Beige 2020-10-21 14:00:00  Beige Book 2020-10-21  Beige Book
# 10    Beige 2020-09-02 14:00:00  Beige Book 2020-09-02  Beige Book
# 11    Beige 2020-07-15 14:00:00  Beige Book 2020-07-15  Beige Book
# 12    Beige 2020-05-27 14:00:00  Beige Book 2020-05-27  Beige Book
# 13    Beige 2020-04-15 14:00:00  Beige Book 2020-04-15  Beige Book
# 14    Beige 2020-03-04 14:00:00  Beige Book 2020-03-04  Beige Book
# 21    Beige 2020-12-02 14:00:00  Beige Book 2020-12-02  Beige Book
# 23    Beige 2020-01-15 14:00:00  Beige Book 2020-01-15  Beige Book

# %%
(df_final['title'] + ', ' + df_final['date'].apply(lambda x:str(x.date()))).apply(lambda x: hash(x))
# Out:
# 0    -2026374702601328519
# 1     1654344810102217206
# 2     -718781993744106731
# 3     1202626196065023634
# 4    -3390781090326368851
# 5      414631357052511788
# 6     -971017299656773265
# 7     2670507746457378305
# 8     2935457177150396471
# 9     6324856380931168407
# 10   -4362039153520736077
# 11    7136433406417625026
# 12    3820210284135730010
# 13    9016251672715358600
# 14    7174661509664547784
# 15    2828770357456159497
# 16    8953210859406729929
# 17   -1884372741657262840
# 18    5779061263560891537
# 19    7209124295930398016
# 20    5931043555395013655
# 21    9042063859104547112
# 22   -8486912756061070848
# 23   -1145584224880200853
# dtype: int64

# %%
df_uniquedes = (df_final['title'] + ', ' + df_final['date'].apply(lambda x:str(x.date())))

# %%
df_final['indexhash'] = (df_final['title'] + ', ' + df_final['date'].apply(lambda x:str(x.date()))).apply(lambda x: hash(x))

# %%
df_final = df_final.set_index('indexhash',drop=True)

# %%
df_final.to_pickle('./events_list.pickle')

# %%
df_events = pd.read_pickle('./events_list.pickle')

# %%
res = set(df_events.index) - set(df_final.index)

# %%
res
# Out:
# set()

# %%
if res:
    print (True)
else:
    print (False)
# Out:
# False

# %%
df_events.loc[res]
# Out:
#                       category                date       description  \
# indexhash
# -6395719108065583385  Speeches 2020-01-17 12:45:00  Bank Supervision
#
#                                                         title
# indexhash
# -6395719108065583385  Speech -- Vice Chair Randal K. Quarles

# %%
df_res = df_events.loc[res]

# %%
df_res.empty
# Out:
# True

# %%
df_events.empty
# Out:
# -1

# %%
df_events.iloc[0]['date'].to_datetime()
# Out:
# C:\Users\ashay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2862: FutureWarning: to_datetime is deprecated. Use self.to_pydatetime()
#   exec(code_obj, self.user_global_ns, self.user_ns)
# datetime.datetime(2020, 1, 17, 12, 45)

# %%
def dummy(x):
    return x['date']

# %%
df_events.apply(dummy,axis=1)
# Out:
# indexhash
# -6395719108065583385   2020-01-17 12:45:00
# -506358195976120439    2020-01-16 10:00:00
# -1823001206848760244   2020-11-25 14:00:00
#  3109511532584406098   2020-10-07 14:00:00
#  6517358195594349697   2020-08-19 14:00:00
# -4231919471837110918   2020-07-01 14:00:00
#  4991622313091795258   2020-05-20 14:00:00
# -9168352783799231704   2020-04-08 14:00:00
# -1366888459877643412   2020-02-19 14:00:00
# -3964144781925994210   2020-10-21 14:00:00
# -1516649023658354743   2020-09-02 14:00:00
# -5622975569362766171   2020-07-15 14:00:00
# -8528225560398762934   2020-05-27 14:00:00
#  2860286917212854601   2020-04-15 14:00:00
# -7229245259843503333   2020-03-04 14:00:00
# -330515501324040690    2020-11-05 14:00:00
# -6853960410240890285   2020-09-16 14:00:00
#  6267401264481000136   2020-07-29 14:00:00
# -1146594305652809613   2020-06-10 14:00:00
# -8502738537393854084   2020-04-29 14:00:00
# -3757092196507350174   2020-03-18 14:00:00
#  6538604015813403983   2020-12-02 14:00:00
#  1870630683592084046   2020-12-16 14:00:00
#  2674007216659760341   2020-01-15 14:00:00
# -488255261298829069    2020-01-29 14:00:00
# dtype: datetime64[ns]
